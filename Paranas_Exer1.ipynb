# %%
ice_cream_rating = 9
sleeping_rating = 10

# %%
first_name = input('First Name')
last_name = input('Last Name')
my_name = first_name + ' ' + last_name
print('My name is', my_name,'.')
# Out:
# First Name Alice
# Last Name Paranas
# My name is Alice Paranas .

# %%
happiness_rating = (ice_cream_rating + sleeping_rating)/2
happiness_percent = (happiness_rating * 10)

# %%
print(type(ice_cream_rating),type(first_name), type(happiness_rating))
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %% [markdown]
# Did all of the data types make sense? Yes
# Were there any data types that were different than you expected? No

# %%
print('My name is', first_name , 'and I give eating ice cream a score of', ice_cream_rating, 'out of 10!')
print ('I am', my_name, 'and my sleeping enjoyment rating is', sleeping_rating, '/ 10!')
print ('Based on the factors above, my happiness rating is', happiness_rating, 'out of 10, or', happiness_percent, '%!')
# Out:
# My name is Alice and I give eating ice cream a score of 9 out of 10!
# I am Alice Paranas and my sleeping enjoyment rating is 10 / 10!
# Based on the factors above, my happiness rating is 9.5 out of 10, or 95.0 %!
